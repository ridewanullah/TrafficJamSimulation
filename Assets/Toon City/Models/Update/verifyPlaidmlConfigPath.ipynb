# %%
import plaidml
import plaidml.settings

config_path = plaidml.settings.load('PLAIDML_CONFIG')
experimental_config_path = plaidml.settings.load('PLAIDML_EXPERIMENTAL_CONFIG')

print(f"Config path: {config_path}")
print(f"Experimental config path: {experimental_config_path}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 import plaidml
#       2 import plaidml.settings
# ----> 4 config_path = plaidml.settings.load('PLAIDML_CONFIG')
#       5 experimental_config_path = plaidml.settings.load('PLAIDML_EXPERIMENTAL_CONFIG')
#       7 print(f"Config path: {config_path}")
#
# AttributeError: '_Settings' object has no attribute 'load'

# %%
import plaidml
import os

# Get the path where plaidml is installed
plaidml_path = os.path.dirname(plaidml.__file__)
print(f"PlaidML is installed at: {plaidml_path}")
# Out:
# PlaidML is installed at: c:\Users\ridew\AppData\Local\Programs\Python\Python310\lib\site-packages\plaidml
